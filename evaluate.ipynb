# %%
# !pip install git+https://github.com/huggingface/datasets.git
# !pip install git+https://github.com/huggingface/transformers.git
# !pip install soundfile
# !pip install jiwer
# Out:
# WARNING: Ignoring invalid distribution -atasets (/opt/conda/lib/python3.10/site-packages)
# ...
#   Cloning https://github.com/huggingface/datasets.git to /tmp/pip-req-build-4pdf03w1
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/datasets.git /tmp/pip-req-build-4pdf03w1
#   Resolved https://github.com/huggingface/datasets.git to commit d5468836fe94e8be1ae093397dd43d4a2503b926
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for datasets: filename=datasets-2.18.1.dev0-py3-none-any.whl size=514296 sha256=551c13e93e347ddceeeaf04933a109e468de926085090429ac7002e12cca3c90
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1zadj75i/wheels/57/f4/c4/53c677af89fec0ef3226c1e75a38367b37c2fa626f0544d3e4
# Successfully built datasets
# WARNING: Ignoring invalid distribution -atasets (/opt/conda/lib/python3.10/site-packages)
# ...

# %%
# !pip uninstall -y cudf dask-cuda dask-cudf
# !pip install protobuf==3.20.*
# !pip install -q cudf-cu12 --extra-index-url=https://pypi.nvidia.com
# Out:
# Found existing installation: cudf 23.6.1
# Uninstalling cudf-23.6.1:
#   Successfully uninstalled cudf-23.6.1
# Found existing installation: dask-cuda 23.6.0
# Uninstalling dask-cuda-23.6.0:
#   Successfully uninstalled dask-cuda-23.6.0
# Found existing installation: dask-cudf 23.6.1
# Uninstalling dask-cudf-23.6.1:
#   Successfully uninstalled dask-cudf-23.6.1
# WARNING: Ignoring invalid distribution -atasets (/opt/conda/lib/python3.10/site-packages)
# ...
# WARNING: Ignoring invalid distribution -atasets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -atasets (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -atasets (/opt/conda/lib/python3.10/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# raft-dask 23.6.2 requires dask-cuda==23.6.*, which is not installed.
# ...

# %%
import torch
from dataclasses import dataclass
from transformers import Wav2Vec2BertForCTC, SeamlessM4TFeatureExtractor, Wav2Vec2CTCTokenizer, TrainingArguments, Trainer
import jiwer
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:3                                                                                    │
# │                                                                                                  │
# │   1 import torch                                                                                 │
# │   2 from dataclasses import dataclass                                                            │
# │ ❱ 3 from transformers import Wav2Vec2BertForCTC, SeamlessM4TFeatureExtractor, Wav2Vec2CTCTok     │
# │   4 import jiwer                                                                                 │
# │   5                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...

# %% [markdown]
# ## Download model and datasets

# %%
from datasets import load_dataset, Audio
from huggingface_hub import login

login('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')
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2BertForCTC

MODEL_ID = "trick4kid/w2v-bert-2.0-vietnamese-CV16.0"  # @param ["facebook/w2v-bert-2.0", "trick4kid/w2v-bert-2.0-vietnamese-CV16.0"]
model = Wav2Vec2BertForCTC.from_pretrained(MODEL_ID, target_lang="vi").to("cuda")
processor = Wav2Vec2Processor.from_pretrained(MODEL_ID)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 from transformers import Wav2Vec2BertConfig, Wav2Vec2BertModel                               │
# │   2                                                                                              │
# │   3 MODEL_ID = "trick4kid/w2v-bert-2.0-vietnamese-CV16.0"  # @param ["facebook/w2v-bert-2.0"     │
# │   4 model = Wav2Vec2BertForCTC.from_pretrained(MODEL_ID, target_lang="vi").to("cuda")            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ImportError: cannot import name 'Wav2Vec2BertConfig' from 'transformers'
# (/opt/conda/lib/python3.10/site-packages/transformers/__init__.py)

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
import torch

use_gpu = torch.cuda.is_available()

model_name = 'hieplpvip/wav2vec2-base-vi-vivos-fosd'
processor = Wav2Vec2Processor.from_pretrained(model_name)
model = Wav2Vec2ForCTC.from_pretrained(model_name)

if use_gpu:
    model = model.cuda()
# Out:
# ...
# loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--hieplpvip--wav2vec2-base-vi-vivos-fosd/snapshots/31cb186ee2b32b53a23a4994f96f4df7133e2512/preprocessor_config.json
# Feature extractor Wav2Vec2FeatureExtractor {
#   "do_normalize": true,
#   "feature_extractor_type": "Wav2Vec2FeatureExtractor",
#   "feature_size": 1,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "processor_class": "Wav2Vec2Processor",
#   "return_attention_mask": false,
#   "sampling_rate": 16000
# }
# ...
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--hieplpvip--wav2vec2-base-vi-vivos-fosd/snapshots/31cb186ee2b32b53a23a4994f96f4df7133e2512/vocab.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--hieplpvip--wav2vec2-base-vi-vivos-fosd/snapshots/31cb186ee2b32b53a23a4994f96f4df7133e2512/tokenizer_config.json
# loading file added_tokens.json from cache at None
# ...

# %% [markdown]
# ## Evaluation

# %%
from datasets import load_dataset, Audio
from huggingface_hub import login

login('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')

common_voice = load_dataset('mozilla-foundation/common_voice_13_0', 'vi', split='test').cast_column('audio', Audio(sampling_rate=16000))
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# ...
# Extracting data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 2462it [00:00, 75016.36it/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 392it [00:00, 64815.20it/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 1225it [00:00, 98501.25it/s]
# Generating other split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 0it [00:00, ?it/s]
# Reading metadata...: 11486it [00:00, 102141.55it/s]
# Generating invalidated split: 0 examples [00:00, ? examples/s]
# Reading metadata...: 350it [00:00, 98339.12it/s]

# %%
common_voice
# Out:
# Dataset({
#     features: ['client_id', 'path', 'audio', 'sentence', 'up_votes', 'down_votes', 'age', 'gender', 'accent', 'locale', 'segment', 'variant'],
#     num_rows: 1225
# })

# %%
import jiwer

def preprocess_text(text):
    # Convert text to lowercase
    text["sentence"] = jiwer.ToLowerCase()(text["sentence"])
    # Remove any word between []. <>
    text["sentence"] = jiwer.RemoveKaldiNonWords()(text["sentence"])
    # Remove spaces between words
    text["sentence"] = jiwer.RemoveMultipleSpaces()(text["sentence"])
    # Remove punctuation !.,
    text["sentence"] = jiwer.RemovePunctuation()(text["sentence"])
    text["sentence"] = jiwer.Strip()(text["sentence"])
    return text
common_voice = common_voice.map(preprocess_text, num_proc=4)
# Out:
# Map (num_proc=4):   0%|          | 0/1225 [00:00<?, ? examples/s]

# %%
#common_voice['sentence']
# ạ dạ không ạ ngại quá',
#  'hương thu còn thoảng đâu đây bên thềm',
#  'gió đông lạnh heo may về khắp lối',
#  'sao anh vội về ngay',

# %%
def prepare_test_set(batch):
    batch['speech'] = batch['audio']['array']
    batch['sampling_rate'] = batch['audio']['sampling_rate']
    batch['target_text'] = batch['sentence']
    return batch

common_voice = common_voice.map(prepare_test_set,remove_columns=common_voice.column_names, num_proc=4)
# Out:
# Map (num_proc=4):   0%|          | 0/1225 [00:00<?, ? examples/s]

# %%
from datasets import load_metric

wer_metric = load_metric('wer')

def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {'wer': wer}

def map_to_result(batch):
    input_values = processor(
        batch['speech'],
        sampling_rate=batch['sampling_rate'],
        return_tensors='pt',
    ).input_values

    if use_gpu:
        model.to('cuda')
        input_values = input_values.to('cuda')

    with torch.no_grad():
        logits = model(input_values).logits

    pred_ids = torch.argmax(logits, dim=-1)
    batch['pred_str'] = processor.batch_decode(pred_ids)[0]

    return batch

# %%
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=50):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset) - 1)
        while pick in picks:
            pick = random.randint(0, len(dataset) - 1)
        picks.append(pick)

    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %% [markdown]
# ## Evaluate on common-voice-vi

# %%
import IPython.display as ipd
import numpy as np
import random

rand_int = random.randint(0, len(common_voice) - 1)

print('Transcript:', common_voice[rand_int]['target_text'])
print('Input array shape:', np.asarray(common_voice[rand_int]['speech']).shape)
print('Sampling rate:', common_voice[rand_int]['sampling_rate'])

ipd.Audio(data=common_voice[rand_int]['speech'], rate=16000)
# Out:
# Transcript: cho mùa thu rơi thoáng nhẹ qua thềm
# Input array shape: (72576,)
# Sampling rate: 16000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
results = common_voice.map(map_to_result)
wer = wer_metric.compute(predictions=results['pred_str'], references=results['target_text'])
print('Test WER: {:.3f}'.format(wer))
# Out:
# Map:   0%|          | 0/1225 [00:00<?, ? examples/s]
# Test WER: 0.188

# %%
wer
# Out:
# 0.1884712884382233

# %%
show_random_elements(results.remove_columns(['speech', 'sampling_rate']))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target_text</th>
#       <th>pred_str</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>nhà của bà len đó</td>
#       <td>nhà của bà len lầu ó</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>anh nấy cũng khoe rằng ảnh của mình hơn</td>
#       <td>anh ấy cũng khoe rằng ảnh của mình hơn</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>cô thu ngân lo lắng gọi</td>
#       <td>cô thương ngăn lo lắng gỏi</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>nhưng lúc này anh ở bên em</td>
#       <td>như lúc làn anh ở bên em</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>bố em lúc ấy chen ngang</td>
#       <td>bố em lúc ấy chen ngang</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>bông cúc chi thạch thảo tím giao hòa</td>
#       <td>bông cuúc chi  thệt thảo tím dào hòa</td>
#     </tr>
# ...

# %% [markdown]
# ## Inference

# %%
path_voice = '/kaggle/input/data-voice/FILE_20240325_213228_20240325-213052.wav'

# %%
import torchaudio

seconds = 30
audio, sample_rate = torchaudio.load(path_voice)
audio = torchaudio.transforms.Resample(sample_rate, 16000)(audio)
audio = audio[:, :(16000 * seconds)]

ipd.Audio(data=audio[0], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
input_values = processor(audio[0], sampling_rate=16000, return_tensors='pt').input_values
if use_gpu:
    input_values = input_values.to('cuda')

# Infer
with torch.no_grad():
    logits = model(input_values).logits

pred_ids = torch.argmax(logits, dim=-1)[0]
print(processor.decode(pred_ids))
# Out:
# trhí tuệ nhân tạo hiện đang là công nghệ được quan tâm phát triển và ừn dực bậc nhất hiện nay được ứng dụng trong nhiều lĩnh vực như nhận rặng khuôn mặt xử lý dọng nói kỹ thuật ưức tính đám đông đến các hệ thống an ninh bảo mật hay hệ thống pháp luật chính phủ theo dòng chảy của của cách mạng chí tuệ nhân tạo ngày càng được phổ biến và ứng dụng rộng rãi trong mọi lĩnh vực của cuộc sống
